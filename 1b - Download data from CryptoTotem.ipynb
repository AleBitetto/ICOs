# %%
import time
from utils import scrape_info_cryptototem
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from bs4 import Tag, NavigableString
from soup2dict import convert
import re
import os
from urllib.parse import urljoin
from timeit import default_timer as timer
import datetime
import requests
import joblib


from utils import decrypt_CryptoTotem

# %%
# set folders
CHECKPOINT_FOLDER = '.\\Checkpoints'
RESULTS_FOLDER = '.\\Results'
CRYTOTOT_FOLDER = '.\\Checkpoints\\Cryptototem'

if not os.path.exists(CHECKPOINT_FOLDER):
    os.makedirs(CHECKPOINT_FOLDER)
if not os.path.exists(RESULTS_FOLDER):
    os.makedirs(RESULTS_FOLDER)
if not os.path.exists(CRYTOTOT_FOLDER):
    os.makedirs(CRYTOTOT_FOLDER)

# %% [markdown]
# ## Get ICOs url

# %%
# Download categories
MAIN_PAGE='https://cryptototem.com/'
CATEGORY_PAGE='https://cryptototem.com/ico-list/'


page = requests.get(CATEGORY_PAGE)
soup = BeautifulSoup(page.content, 'html.parser')

tt=convert(soup.find("div", class_="sort-elements"))
option_list=tt['option']

df_cat=pd.DataFrame()
start = timer()
for i, el in enumerate(option_list):
    
    print(f'- Downloading: {i+1} / {len(option_list)}   ', end='\r')
    
    
    url=urljoin(MAIN_PAGE, el['@data-url'])
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    total_pages=1
    if '         Next\n' in soup.prettify() and '\n         Previous' in soup.prettify():
        tt=convert(soup)
        ss=tt['html'][0]['#text']
        sta_ind=ss.find('Previous 1')
        end_ind=ss[sta_ind:].find('Next')
        pages=ss[sta_ind:(sta_ind+end_ind)].replace('Previous', '').strip()
        total_pages=int(pages[-1])
    add_row=pd.DataFrame({'Category': el['#text'],
                         'url': url,
                         'pages': total_pages}, index=[i])
    df_cat=pd.concat([df_cat, add_row])
print('\nTotal elapsed time:', str(datetime.timedelta(seconds=round(timer()-start))))
df_cat=df_cat.sort_values(by='pages', ascending=False).reset_index(drop=True)
display(df_cat)
# Out:
# - Downloading: 81 / 81
# Total elapsed time: 0:01:48
#                           Category  \
# 0                            Other
# 1   Social Network & Communication
# 2           Crowdfunding & Lending
# 3              Exchanges & Wallets
# 4               Gambling & Betting
# ..                             ...
# 76                            Meme
# 77                       Metaverse
# 78                Cosmos Ecosystem
# 79                  Near Ecosystem
# 80                           Adult
#
#                                                   url  pages
# 0                      https://cryptototem.com/other/      8
# 1   https://cryptototem.com/social-network-and-com...      7
# 2   https://cryptototem.com/crowdfunding-and-lending/      6
# 3      https://cryptototem.com/exchanges-and-wallets/      5
# 4       https://cryptototem.com/gambling-and-betting/      5
# ..                                                ...    ...
# 76                      https://cryptototem.com/meme/      1
# 77                 https://cryptototem.com/metaverse/      1
# 78          https://cryptototem.com/cosmos-ecosystem/      1
# 79            https://cryptototem.com/near-ecosystem/      1
# 80                     https://cryptototem.com/adult/      1
#
# [81 rows x 3 columns]

# %%
# apply category in search query and get ICO list

df_list=pd.DataFrame()
start=timer()
download_date=datetime.datetime.now().strftime("%d/%m/%Y")
for index, row in df_cat.iterrows():
    url_list=[row['url']]
    if row['pages'] > 1:
        url_list.extend([urljoin(row['url'], f'page/{x+1}/') for x in range(1, row['pages'])])

    for page_i, url in enumerate(url_list):

        categ=row['Category']
        print(f'- Downloading Category: {categ} ({index+1} / {len(df_cat)})  - page: {page_i+1} / {len(url_list)}   ', end='\r')

        page = requests.get(url)
        soup = BeautifulSoup(page.content, 'html.parser')
        table=convert(soup.find("table", class_="ico-table sortable"))['tbody'][0]['tr']

        for tt_row in table:
            link=urljoin(MAIN_PAGE, tt_row['td'][1]['a'][0]['@href'])
            name=tt_row['td'][1]['#text'].split('(')
            if len(name) > 1:
                name=''.join(name[:-1])
            else:
                name=name[0]
            name=name.strip()
            try:
                interest=tt_row['td'][3]['div'][1]['#text']
            except:
                interest=''
            add_row=pd.DataFrame({'Category': row['Category'],
                                 'url': link,
                                 'name': name,
                                 'interest': interest}, index=[0])
            df_list=pd.concat([df_list, add_row])
    print('')
df_list['ListDownloadedOn']=download_date
print('\nTotal elapsed time:', str(datetime.timedelta(seconds=round(timer()-start))))

pkl_path=os.path.join(CRYTOTOT_FOLDER, 'cryptototem_url_list.pkl')
joblib.dump(df_list, pkl_path, compress=('lzma', 3))
print('\nData saved in', pkl_path)

display(df_list.head(5))
print('Total rows:', len(df_list))
print('\nTotal Categories:', df_list['Category'].nunique())
print('Total unique urls:', df_list['url'].nunique())
print('Total unique names:', df_list['name'].nunique())

multiple_names = df_list.drop(columns='Category').drop_duplicates()['name'].value_counts().to_frame().query("name > 1").index.tolist()
if len(multiple_names) > 0:
    df_multiple = df_list[df_list['name'].isin(multiple_names)].sort_values(by='name')
    n_uniq = df_multiple['name'].nunique()
    print(f'\n\n- {n_uniq} ICOs with multiple names found')
    display(df_multiple.drop(columns='ListDownloadedOn'))
    
    df_multiple.to_csv(os.path.join(RESULTS_FOLDER, '01b_CryptoTotem_ico_list_multiple_names.csv'), index=False, sep=';')
    print('\nMultiple ICOs saved in ', os.path.join(RESULTS_FOLDER, '01b_a_CryptoTotem_ico_list_multiple_names.csv'))
# Out:
# - Downloading Category: Other (81 / 81)  - page: 8 / 8
# - Downloading Category: Social Network & Communication (65 / 81)  - page: 4 / 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 16
#      13 categ=row['Category']
#      14 print(f'- Downloading Category: {categ} ({index+1} / {len(df_cat)})  - page: {page_i+1} / {len(url_list)}   ', end='\r')
# ---> 16 page = requests.get(url)
#      17 soup = BeautifulSoup(page.content, 'html.parser')
#      18 table=convert(soup.find("table", class_="ico-table sortable"))['tbody'][0]['tr']
#
# File ~\AppData\Roaming\Python\Python39\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Roaming\Python\Python39\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Roaming\Python\Python39\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\urllib3\connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File C:\ProgramData\Anaconda3\envs\ico\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File C:\ProgramData\Anaconda3\envs\ico\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File C:\ProgramData\Anaconda3\envs\ico\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File C:\ProgramData\Anaconda3\envs\ico\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File C:\ProgramData\Anaconda3\envs\ico\lib\ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File C:\ProgramData\Anaconda3\envs\ico\lib\ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Scrape information from url

# %%
URL_ROOT = "https://cryptototem.com/"
RELOAD_PKL=True


df_list=joblib.load(os.path.join(CRYTOTOT_FOLDER, 'cryptototem_url_list.pkl'))
df_scrape_raw = pd.DataFrame()
unique_urls = df_list['url'].unique()
for index, url in enumerate(unique_urls):
    
    print(f'- Scraping: {str(index + 1)} / {len(unique_urls)}   last interaction: {datetime.datetime.now().strftime("%d/%m/%Y %H:%M:%S")}      ', end='\r')
    save_path=os.path.join(CRYTOTOT_FOLDER, url.replace(URL_ROOT, '').strip("/").replace('/', '_')+'.pkl').replace('|', '')

    if not RELOAD_PKL or not os.path.exists(save_path):
        try:
            start = timer()
            add_row = scrape_info_cryptototem(url)
            add_row.insert(1, 'scrape_status', 'OK')
            add_row['PklPath']=save_path
            add_row['TotTimeSec']=datetime.timedelta(seconds=round(timer()-start)).total_seconds()

            joblib.dump(add_row, save_path, compress=('lzma', 3))
        except Exception as err:
            add_row = pd.DataFrame({'url': url, 'scrape_status': 'ERROR', 'scrape_error': err}, index=[0])
            
    else:
        add_row=joblib.load(save_path)
    
    df_scrape_raw=pd.concat([df_scrape_raw, add_row])
    
df_scrape_raw.reset_index(drop=True, inplace=True)
display(df_scrape_raw['scrape_status'].value_counts().to_frame())
print('Check "scrape_error"')
display(df_scrape_raw['website_err'].value_counts().to_frame())
display(df_scrape_raw['whitepaper_err'].value_counts().to_frame())
display(df_scrape_raw['overview_err'].value_counts().to_frame())
display(df_scrape_raw['description_err'].value_counts().to_frame())
display(df_scrape_raw['info_err'].value_counts().to_frame())
display(df_scrape_raw['milestone_err'].value_counts().to_frame())
display(df_scrape_raw['team_err'].value_counts().to_frame())
display(df_scrape_raw['social_err'].value_counts().to_frame())

print('\n\nTotal elapsed time:', str(datetime.timedelta(seconds=round(df_scrape_raw['TotTimeSec'].sum()))))

# save
pkl_path=os.path.join(CRYTOTOT_FOLDER, 'cryptototem_scrape_df_raw.pkl')
joblib.dump(df_scrape_raw, pkl_path, compress=('lzma', 3))
print(f'\nData saved in {pkl_path}')
# Out:
# - Scraping: 5142 / 5142   last interaction: 12/04/2024 12:51:39
#        scrape_status
# OK              5141
# ERROR              1
# Check "scrape_error"
#                                                     website_err
#                                                            5139
# Missing matched typeclass instance for type: No...            1
# Missing matched typeclass instance for type: No...            1
#                whitepaper_err
#                          4585
# NOT AVAILABLE             556
#   overview_err
#           5141
#   description_err
#              5141
#   info_err
#       5141
#        milestone_err
#                 5139
# 'div'              1
# 'div'              1
#   team_err
#       5141
#               social_err
#                     5086
# only website          55
# Total elapsed time: 3:13:49
#
# Data saved in .\Checkpoints\cryptototem_scrape_df_raw.pkl

# %%
pd.set_option('display.max_columns', None)
df_scrape_raw
# Out:
#                                                url scrape_status  \
# 0                https://cryptototem.com/lido-ldo/            OK
# 1              https://cryptototem.com/subdao-gov/            OK
# 2          https://cryptototem.com/story-protocol/            OK
# 3      https://cryptototem.com/solv-protocol-solv/            OK
# 4     https://cryptototem.com/unstoppable-domains/            OK
# ...                                            ...           ...
# 5137  https://cryptototem.com/sexservice-ssio-ico/            OK
# 5138  https://cryptototem.com/vanillaplay-vpy-ico/            OK
# 5139      https://cryptototem.com/okoin-okoin-ico/            OK
# 5140      https://cryptototem.com/erotix--erx-ico/            OK
# 5141     https://cryptototem.com/povcoin-povr-ico/            OK
#
#        last_update      tag status  \
# 0     Aug 11, 2023       []   None
# 1     Dec 01, 2022  [DAICO]   None
# 2     Sep 08, 2023       []   None
# 3     Dec 31, 2022       []   None
# 4     Nov 21, 2022       []   None
# ...            ...      ...    ...
# 5137  May 04, 2018    [ICO]   None
# 5138  May 04, 2018    [ICO]   None
# 5139  May 04, 2018    [ICO]   None
# 5140  May 04, 2018    [ICO]   None
# 5141  Apr 23, 2019    [ICO]   None
#
#                                                 website website_err  \
# 0               https://lido.fi/?utm_source=CryptoTotem
# 1                           https://www.subdao.network/
# 2                        https://www.storyprotocol.xyz/
# 3          https://solv.finance/?utm_source=CryptoTotem
# 4     https://unstoppabledomains.com/?utm_source=Cry...
# ...                                                 ...         ...
# 5137  https://sexservice.io&utm_medium=listing&utm_c...
# 5138  https://www.vanillaplay.io/&utm_medium=listing...
# 5139  https://okoin.io/&utm_medium=listing&utm_campa...
# 5140  https://erotix.io/&utm_medium=listing&utm_camp...
# 5141  https://povcoin.io/&utm_medium=listing&utm_cam...
#
#                                          whitepaper_url whitepaper_err  \
# 0     https://cryptototem.com/wp-ico/img/new project...
# 1     https://cryptototem.com/wp-ico/img/new project...
# 2                                                        NOT AVAILABLE
# 3                            https://docs.solv.finance/
# 4                  https://docs.unstoppabledomains.com/
# ...                                                 ...            ...
# 5137  https://sexservice.io/wp/ssio-whitepaper-en-1....
# 5138  https://www.vanillaplay.io/whitepaper/VanillaP...
# 5139  https://cryptototem.com/wp-ico/img/files/7gr4n...
# 5140  https://cryptototem.com/wp-ico/img/files/AyaeT...
# 5141  https://cryptototem.com/wp-ico/img/files/QkeyK...
#
#       bounty_dummy  MVP_dummy  \
# 0              0.0        1.0
# 1              0.0        0.0
# 2              0.0        0.0
# 3              0.0        1.0
# 4              0.0        0.0
# ...            ...        ...
# 5137           0.0        0.0
# 5138           0.0        0.0
# 5139           0.0        0.0
# 5140           0.0        0.0
# 5141           0.0        0.0
#
#                                          overview_block overview_err  \
# 0                   Field           Value
# 0  Project...
# 1                   Field         Value
# 0  Project i...
# 2                   Field          Value
# 0  Project ...
# 3                   Field        Value
# 0  Project in...
# 4                   Field          Value
# 0  Project ...
# ...                                                 ...          ...
# 5137                Field  Value
# 0  Project industry...
# 5138                Field  Value
# 0  Project industry...
# 5139                Field           Value
# 0  Project...
# 5140                Field     Value
# 0  Project indus...
# 5141                Field     Value
# 0  Project indus...
#
#       price_series_avail                                        description  \
# 0                    1.0  What is Lido Lido"s liquid staking allows usin...
# 1                    0.0  What is SubDAO SubDAO is a DAO infrastructure ...
# 2                    0.0  What is Story Protocol Story Protocol was foun...
# 3                    0.0  What is Solv Protocol Solv Protocol is a decen...
# 4                    0.0  What is Unstoppable Domains Unstoppable Domain...
# ...                  ...                                                ...
# 5137                 0.0  What is Sexservice Wallet, Explorer and Live n...
# 5138                 0.0  What is VanillaPlay VanillaPlay eliminates the...
# 5139                 0.0  What is OKOIN Decentralized p2p distribution o...
# 5140                 0.0  What is Erotix The main application of the pla...
# 5141                 0.0  What is POVCOIN POVCOIN develops a platform wh...
#
#      description_err                                         info_block  \
# 0                          category                   label         ...
# 1                          category                 label  \
# 0     D...
# 2                       category               label           value...
# 3                          category                 label  \
# 0     D...
# 4                       category               label           value...
# ...              ...                                                ...
# 5137                       category                 label  \
# 0  Toke...
# 5138                       category                 label  \
# 0  Toke...
# 5139                       category                  label  \
# 0     ...
# 5140                       category                   label  \
# 0    ...
# 5141                       category                   label  \
# 0    ...
#
#      info_err                                    milestone_block  \
# 0                          Empty DataFrame
# Columns: []
# Index: []
# 1                          Empty DataFrame
# Columns: []
# Index: []
# 2                          Empty DataFrame
# Columns: []
# Index: []
# 3                          Empty DataFrame
# Columns: []
# Index: []
# 4                          Empty DataFrame
# Columns: []
# Index: []
# ...       ...                                                ...
# 5137                    date                                 ...
# 5138                        date                             ...
# 5139                       date                              ...
# 5140                 date                                    ...
# 5141                         date                            ...
#
#      milestone_err                                         team_block  \
# 0                       Member                Name  \
# 0     Team  ...
# 1                       Member          Name         Role Links
# 0 ...
# 2                       Member                     Name           ...
# 3                       Member                 Name               ...
# 4                      Member             Name                    ...
# ...            ...                                                ...
# 5137                            Empty DataFrame
# Columns: []
# Index: []
# 5138                            Empty DataFrame
# Columns: []
# Index: []
# 5139                            Empty DataFrame
# Columns: []
# Index: []
# 5140                            Empty DataFrame
# Columns: []
# Index: []
# 5141                    Member                Name              Ro...
#
#      team_err                                        social_info social_err  \
# 0                   Social                                   ...
# 1                   Social                                Lin...
# 2                   Social                                   ...
# 3                   Social                                   ...
# 4                    Social                                  ...
# ...       ...                                                ...        ...
# 5137               Social                                    ...
# 5138                Social                                   ...
# 5139                Social                               Link...
# 5140                Social                                Lin...
# 5141                 Social                                  ...
#
#                                                 PklPath  TotTimeSec  \
# 0                .\Checkpoints\Cryptototem\lido-ldo.pkl         2.0
# 1              .\Checkpoints\Cryptototem\subdao-gov.pkl         2.0
# 2          .\Checkpoints\Cryptototem\story-protocol.pkl         1.0
# 3      .\Checkpoints\Cryptototem\solv-protocol-solv.pkl         2.0
# 4     .\Checkpoints\Cryptototem\unstoppable-domains.pkl         2.0
# ...                                                 ...         ...
# 5137  .\Checkpoints\Cryptototem\sexservice-ssio-ico.pkl         2.0
# 5138  .\Checkpoints\Cryptototem\vanillaplay-vpy-ico.pkl         2.0
# 5139      .\Checkpoints\Cryptototem\okoin-okoin-ico.pkl         2.0
# 5140      .\Checkpoints\Cryptototem\erotix--erx-ico.pkl         2.0
# 5141     .\Checkpoints\Cryptototem\povcoin-povr-ico.pkl         2.0
#
#      scrape_error
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 5137          NaN
# 5138          NaN
# 5139          NaN
# 5140          NaN
# 5141          NaN
#
# [5142 rows x 27 columns]

# %%
df_scrape_raw['milestone_err'].value_counts()
# Out:
#     60
# Name: milestone_err, dtype: int64

# %%
url='https://cryptototem.com/breederdao-breed/'
pd.set_option('display.max_columns', None)
aa=scrape_info_cryptototem(url)
aa
# Out:
#                                   url   last_update    tag status  \
# 0  https://cryptototem.com/sheng-ieo/  Jun 14, 2020  [IEO]   None
#
#                    website website_err  \
# 0  https://www.sheng.asia/
#
#                                       whitepaper_url whitepaper_err  \
# 0  https://cryptototem.com/wp-ico/img/new project...
#
#    bounty_dummy  MVP_dummy                                     overview_block  \
# 0             0          0                Field      Value
# 0  Project indu...
#
#   overview_err  price_series_avail  \
# 0                                0
#
#                                          description description_err  \
# 0  What is SHENG Shengworld is a Business-to-Busi...
#
#                                           info_block info_err  \
# 0       category                    label        ...
#
#                                      milestone_block milestone_err  \
# 0                            date                ...
#
#                                           team_block team_err  \
# 0      Member                Name  \
# 0     Team  ...
#
#                                          social_info social_err
# 0       Social                                   ...

# %%
aa['milestone_block'][0]
# Out:
#                           date                 milestone
# 0                Map_June 2019  Customer journey mapping
# 1           MDP_September 2019            Demo Solutions
# 2                 MVP_May 2020                  e-Wallet
# 3  Admin Interface_August 2020       Web-based Interface
# 4             MVP_October 2020      E-store setup on web

# %%
url='https://cryptototem.com/infinidium-ico/'
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
try:
    tt=convert(soup.find("div", class_="soc-urls"))
    if len(tt) > 0:
        for el in tt['a']:
            try:
                social_name=el['@title'].split(':')[0]
            except:
                social_name=''
            try:
                social_url=el['@href']
            except:
                social_url=''
            social_info=pd.concat([social_info, pd.DataFrame({'Social': social_name, 'Link': social_url}, index=[0])])
except Exception as err:
    social_err=err

# %%
social_err
# Out:
# KeyError('a')

# %%
tt=convert(soup.find("div", class_="soc-urls"))
tt
# Out:
# {'@class': ['soc-urls'],
#  '#text': '',
#  'span': [{'@class': ['decr'],
#    '@data-u': '{"ct":"OwmH3tDsEpgeX+N58iGvHzrrFaNBRwxU4eBBj76T83tESIq9wQ\\/Pu\\/tvaabFh+P6w1QbMxoEVyoYyL\\/rzkzbdA==","iv":"9e6e5bd93e83cc190a26c3a828fc764c","s":"fa144f18a47ebd28"}',
#    '#text': '',
#    'img': [{'@src': '/wp-content/themes/ultimate-conversion/assets/img/logos/website.svg',
#      '@alt': 'SHENG web-site',
#      '@width': '38',
#      '@height': '38',
#      '#text': ''}]}],
#  'a': [{'@href': 'https://www.reddit.com/r/Sheng_Global/',
#    '@title': 'Reddit: SHENG',
#    '@rel': ['noopener', 'noreferrer', 'nofollow'],
#    '@onclick': "this.target='_blank'",
#    '#text': '',
#    'img': [{'@src': '/wp-content/themes/ultimate-conversion/assets/img/loading-arrow.svg',
#      '@data-src': '/wp-content/themes/ultimate-conversion/assets/img/logos/reddit.svg',
#      '@alt': 'SHENG Reddit',
#      '@class': ['lazyload'],
#      '@width': '38',
#      '@height': '38',
#      '#text': ''}]},
#   {'@href': 'https://medium.com/@sheng_world',
#    '@title': 'Medium: SHENG',
#    '@rel': ['noopener', 'noreferrer', 'nofollow'],
#    '@onclick': "this.target='_blank'",
#    '#text': '',
#    'img': [{'@src': '/wp-content/themes/ultimate-conversion/assets/img/loading-arrow.svg',
#      '@data-src': '/wp-content/themes/ultimate-conversion/assets/img/logos/medium.svg',
#      '@alt': 'SHENG Medium',
#      '@class': ['lazyload'],
#      '@width': '38',
#      '@height': '38',
#      '#text': ''}]},
#   {'@href': 'https://t.me/sheng_world',
#    '@title': 'Telegram: SHENG',
#    '@rel': ['noopener', 'noreferrer', 'nofollow'],
#    '@onclick': "this.target='_blank'",
#    '#text': '',
#    'img': [{'@src': '/wp-content/themes/ultimate-conversion/assets/img/loading-arrow.svg',
#      '@data-src': '/wp-content/themes/ultimate-conversion/assets/img/logos/telegram.svg',
#      '@alt': 'SHENG Telegram',
#      '@class': ['lazyload'],
#      '@width': '38',
#      '@height': '38',
#      '#text': ''}]},
#   {'@href': 'https://bitcointalk.org/index.php?topic=5213429.new#new',
#    '@title': 'BTCTalk: SHENG',
#    '@rel': ['noopener', 'noreferrer', 'nofollow'],
#    '@onclick': "this.target='_blank'",
#    '#text': '',
#    'img': [{'@src': '/wp-content/themes/ultimate-conversion/assets/img/loading-arrow.svg',
#      '@data-src': '/wp-content/themes/ultimate-conversion/assets/img/logos/btctalk.svg',
#      '@alt': 'SHENG BTCTalk',
#      '@class': ['lazyload'],
#      '@width': '38',
#      '@height': '38',
#      '#text': ''}]},
#   {'@href': 'https://www.linkedin.com/company/sheng-global',
#    '@title': 'LinkedIn: SHENG',
#    '@rel': ['noopener', 'noreferrer', 'nofollow'],
#    '@onclick': "this.target='_blank'",
#    '#text': '',
#    'img': [{'@src': '/wp-content/themes/ultimate-conversion/assets/img/loading-arrow.svg',
#      '@data-src': '/wp-content/themes/ultimate-conversion/assets/img/logos/linkedin.svg',
#      '@alt': 'SHENG LinkedIn',
#      '@class': ['lazyload'],
#      '@width': '38',
#      '@height': '38',
#      '#text': ''}]},
#   {'@href': 'https://twitter.com/sheng_global',
#    '@title': 'Twitter: SHENG',
#    '@rel': ['noopener', 'noreferrer', 'nofollow'],
#    '@onclick': "this.target='_blank'",
#    '#text': '',
#    'img': [{'@src': '/wp-content/themes/ultimate-conversion/assets/img/loading-arrow.svg',
#      '@data-src': '/wp-content/themes/ultimate-conversion/assets/img/logos/twitter.svg',
#      '@alt': 'SHENG Twitter',
#      '@class': ['lazyload'],
#      '@width': '38',
#      '@height': '38',
#      '#text': ''}]},
#   {'@href': 'https://www.facebook.com/shengworld/',
#    '@title': 'Facebook: SHENG',
#    '@rel': ['noopener', 'noreferrer', 'nofollow'],
#    '@onclick': "this.target='_blank'",
#    '#text': '',
#    'img': [{'@src': '/wp-content/themes/ultimate-conversion/assets/img/loading-arrow.svg',
#      '@data-src': '/wp-content/themes/ultimate-conversion/assets/img/logos/facebook.svg',
#      '@alt': 'SHENG Facebook',
#      '@class': ['lazyload'],
#      '@width': '38',
#      '@height': '38',
#      '#text': ''}]},
#   {'@href': 'https://github.com/sheng-global/token',
#    '@title': 'Github: SHENG',
#    '@rel': ['noopener', 'noreferrer', 'nofollow'],
#    '@onclick': "this.target='_blank'",
#    '#text': '',
#    'img': [{'@src': '/wp-content/themes/ultimate-conversion/assets/img/loading-arrow.svg',
#      '@data-src': '/wp-content/themes/ultimate-conversion/assets/img/logos/github.svg',
#      '@alt': 'SHENG Github',
#      '@class': ['lazyload'],
#      '@width': '38',
#      '@height': '38',
#      '#text': ''}]}]}

# %%
milestone_err=''
milestone_block=pd.DataFrame()
try:
    tt=soup.find("div", class_="milestones")
    if tt:
        tt=convert(tt.find("div", class_="box"))
        for i, el in enumerate(tt['div']):
            try:
                ref=list(set(el['div'][1].keys()) - set(['@class', '#text', 'div']))[0]  # can be 'p' or 'li' or 'ul'
                milestone=el['div'][1][ref][0]['#text']
            except:
                milestone=''
            try:
                date=el['div'][1]['div'][1]['#text']
            except:
                date=''
            milestone_block=pd.concat([milestone_block, pd.DataFrame({'date': date, 'milestone': milestone}, index=[i])])
except Exception as err:
    milestone_err=err
milestone_block
# Out:
#       date                   milestone
# 0  Q4 2020  Founded Locklet Lite Paper

# %%
ref=list(set(el['div'][1].keys()) - set(['@class', '#text', 'div']))[0]  # can be 'p' or 'li' or 'ul'
if '#text' in el['div'][1][ref][0]:
    milestone=el['div'][1][ref][0]['#text']
else:
    ref2=list(set(el['div'][1][ref][0].keys()) - set(['@class', '#text', 'div']))[0]
    milestone=el['div'][1][ref][0][ref2][0]['#text']

# %%
el['div'][1]['ul']#['div'][1]['#text']
# Out:
# [{'#text': 'Q1 2021 Locklet Testnet for ERC20 and BEP20 tokens Advisors Onboarding',
#   'div': [{'@class': ['condition'],
#     '#text': 'Q1 2021',
#     'navigablestring': ['Q1 2021']}],
#   'li': [{'#text': 'Locklet Testnet for ERC20 and BEP20 tokens',
#     'navigablestring': ['Locklet Testnet for ERC20 and BEP20 tokens']},
#    {'#text': 'Advisors Onboarding',
#     'navigablestring': ['Advisors Onboarding']}]}]

# %%
ref
# Out:
# 'ul'

# %%
el
# Out:
# {'@class': ['row'],
#  '#text': '2 Q1 2021 Locklet Testnet for ERC20 and BEP20 tokens Advisors Onboarding',
#  'div': [{'@class': ['number'], '#text': '2', 'navigablestring': ['2']},
#   {'@class': ['bubble'],
#    '#text': 'Q1 2021 Locklet Testnet for ERC20 and BEP20 tokens Advisors Onboarding',
#    'div': [{'@class': ['arrow'], '#text': ''}],
#    'ul': [{'#text': 'Q1 2021 Locklet Testnet for ERC20 and BEP20 tokens Advisors Onboarding',
#      'div': [{'@class': ['condition'],
#        '#text': 'Q1 2021',
#        'navigablestring': ['Q1 2021']}],
#      'li': [{'#text': 'Locklet Testnet for ERC20 and BEP20 tokens',
#        'navigablestring': ['Locklet Testnet for ERC20 and BEP20 tokens']},
#       {'#text': 'Advisors Onboarding',
#        'navigablestring': ['Advisors Onboarding']}]}]}]}

# %%
milestone
# Out:
# 'Q1 2021 Locklet Testnet for ERC20 and BEP20 tokens Advisors Onboarding'

# %%
ref2=list(set(el['div'][1][ref][0].keys()) - set(['@class', '#text', 'div']))[0]
ref2
# Out:
# 'li'

# %%
el['div'][1][ref][0][ref2]
# Out:
# [{'#text': 'Locklet Testnet for ERC20 and BEP20 tokens',
#   'navigablestring': ['Locklet Testnet for ERC20 and BEP20 tokens']},
#  {'#text': 'Advisors Onboarding', 'navigablestring': ['Advisors Onboarding']}]

# %%
el['div'][1]['ul'][0]
# Out:
# {'#text': 'Q1 2021 Locklet Testnet for ERC20 and BEP20 tokens Advisors Onboarding',
#  'div': [{'@class': ['condition'],
#    '#text': 'Q1 2021',
#    'navigablestring': ['Q1 2021']}],
#  'li': [{'#text': 'Locklet Testnet for ERC20 and BEP20 tokens',
#    'navigablestring': ['Locklet Testnet for ERC20 and BEP20 tokens']},
#   {'#text': 'Advisors Onboarding',
#    'navigablestring': ['Advisors Onboarding']}]}

# %%
el
# Out:
# {'@class': ['row'],
#  '#text': '2 Q1 2021 Locklet Testnet for ERC20 and BEP20 tokens Advisors Onboarding',
#  'div': [{'@class': ['number'], '#text': '2', 'navigablestring': ['2']},
#   {'@class': ['bubble'],
#    '#text': 'Q1 2021 Locklet Testnet for ERC20 and BEP20 tokens Advisors Onboarding',
#    'div': [{'@class': ['arrow'], '#text': ''}],
#    'ul': [{'#text': 'Q1 2021 Locklet Testnet for ERC20 and BEP20 tokens Advisors Onboarding',
#      'div': [{'@class': ['condition'],
#        '#text': 'Q1 2021',
#        'navigablestring': ['Q1 2021']}],
#      'li': [{'#text': 'Locklet Testnet for ERC20 and BEP20 tokens',
#        'navigablestring': ['Locklet Testnet for ERC20 and BEP20 tokens']},
#       {'#text': 'Advisors Onboarding',
#        'navigablestring': ['Advisors Onboarding']}]}]}]}

# %%
milestone_err
# Out:
# IndexError('list index out of range')

# %%
el['div'][1]['div'][1]['#text']
# Out:
# 'Map_June 2019'

# %%
list(set(el['div'][1].keys()) - set(['@class', '#text', 'div']))[0]
# Out:
# 'li'

# %%
el['div'][1]#['li'][0]['#text']
# Out:
# {'@class': ['bubble'],
#  '#text': 'Map_June 2019 Customer journey mapping Wireframes mapping',
#  'div': [{'@class': ['arrow'], '#text': ''},
#   {'@class': ['condition'],
#    '#text': 'Map_June 2019',
#    'navigablestring': ['Map_June 2019']}],
#  'li': [{'#text': 'Customer journey mapping',
#    'navigablestring': ['Customer journey mapping']},
#   {'#text': 'Wireframes mapping', 'navigablestring': ['Wireframes mapping']}]}

# %%
el['div'][1]#['p'][0]['#text']
# Out:
# {'@class': ['bubble'],
#  '#text': 'Map_June 2019 Customer journey mapping Wireframes mapping',
#  'div': [{'@class': ['arrow'], '#text': ''},
#   {'@class': ['condition'],
#    '#text': 'Map_June 2019',
#    'navigablestring': ['Map_June 2019']}],
#  'li': [{'#text': 'Customer journey mapping',
#    'navigablestring': ['Customer journey mapping']},
#   {'#text': 'Wireframes mapping', 'navigablestring': ['Wireframes mapping']}]}

# %%
el
# Out:
# {'@class': ['row'],
#  '#text': '1 Map_June 2019 Customer journey mapping Wireframes mapping',
#  'div': [{'@class': ['number'], '#text': '1', 'navigablestring': ['1']},
#   {'@class': ['bubble'],
#    '#text': 'Map_June 2019 Customer journey mapping Wireframes mapping',
#    'div': [{'@class': ['arrow'], '#text': ''},
#     {'@class': ['condition'],
#      '#text': 'Map_June 2019',
#      'navigablestring': ['Map_June 2019']}],
#    'li': [{'#text': 'Customer journey mapping',
#      'navigablestring': ['Customer journey mapping']},
#     {'#text': 'Wireframes mapping',
#      'navigablestring': ['Wireframes mapping']}]}]}

# %%
tt
# Out:
# {'@class': ['box'],
#  '#text': '1 Map_June 2019 Customer journey mapping Wireframes mapping 2 MDP_September 2019 Demo Solutions Wireframes 3 MVP_May 2020 e-Wallet Internal exchange Internal exchange Integrated merchant platform Merchant admin portal Marketplace merchant admin portal 4 Admin Interface_August 2020 Web-based Interface Authentication & authorisation and enhance security protocol Web-based integrated merchant platform Web-based merchant admin platform 5 MVP_October 2020 E-store setup on web Product ratings and review Creation of categories Optimisation module Social management portal',
#  'div': [{'@class': ['row'],
#    '#text': '1 Map_June 2019 Customer journey mapping Wireframes mapping',
#    'div': [{'@class': ['number'], '#text': '1', 'navigablestring': ['1']},
#     {'@class': ['bubble'],
#      '#text': 'Map_June 2019 Customer journey mapping Wireframes mapping',
#      'div': [{'@class': ['arrow'], '#text': ''},
#       {'@class': ['condition'],
#        '#text': 'Map_June 2019',
#        'navigablestring': ['Map_June 2019']}],
#      'li': [{'#text': 'Customer journey mapping',
#        'navigablestring': ['Customer journey mapping']},
#       {'#text': 'Wireframes mapping',
#        'navigablestring': ['Wireframes mapping']}]}]},
#   {'@class': ['row'],
#    '#text': '2 MDP_September 2019 Demo Solutions Wireframes',
#    'div': [{'@class': ['number'], '#text': '2', 'navigablestring': ['2']},
#     {'@class': ['bubble'],
#      '#text': 'MDP_September 2019 Demo Solutions Wireframes',
#      'div': [{'@class': ['arrow'], '#text': ''},
#       {'@class': ['condition'],
#        '#text': 'MDP_September 2019',
#        'navigablestring': ['MDP_September 2019']}],
#      'li': [{'#text': 'Demo Solutions', 'navigablestring': ['Demo Solutions']},
#       {'#text': 'Wireframes', 'navigablestring': ['Wireframes']}]}]},
#   {'@class': ['row'],
#    '#text': '3 MVP_May 2020 e-Wallet Internal exchange Internal exchange Integrated merchant platform Merchant admin portal Marketplace merchant admin portal',
#    'div': [{'@class': ['number'], '#text': '3', 'navigablestring': ['3']},
#     {'@class': ['bubble'],
#      '#text': 'MVP_May 2020 e-Wallet Internal exchange Internal exchange Integrated merchant platform Merchant admin portal Marketplace merchant admin portal',
#      'div': [{'@class': ['arrow'], '#text': ''},
#       {'@class': ['condition'],
#        '#text': 'MVP_May 2020',
#        'navigablestring': ['MVP_May 2020']}],
#      'li': [{'#text': 'e-Wallet', 'navigablestring': ['e-Wallet']},
#       {'#text': 'Internal exchange', 'navigablestring': ['Internal exchange']},
#       {'#text': 'Internal exchange', 'navigablestring': ['Internal exchange']},
#       {'#text': 'Integrated merchant platform',
#        'navigablestring': ['Integrated merchant platform']},
#       {'#text': 'Merchant admin portal',
#        'navigablestring': ['Merchant admin portal']},
#       {'#text': 'Marketplace merchant admin portal',
#        'navigablestring': ['Marketplace merchant admin portal']}]}]},
#   {'@class': ['row'],
#    '#text': '4 Admin Interface_August 2020 Web-based Interface Authentication & authorisation and enhance security protocol Web-based integrated merchant platform Web-based merchant admin platform',
#    'div': [{'@class': ['number'], '#text': '4', 'navigablestring': ['4']},
#     {'@class': ['bubble'],
#      '#text': 'Admin Interface_August 2020 Web-based Interface Authentication & authorisation and enhance security protocol Web-based integrated merchant platform Web-based merchant admin platform',
#      'div': [{'@class': ['arrow'], '#text': ''},
#       {'@class': ['condition'],
#        '#text': 'Admin Interface_August 2020',
#        'navigablestring': ['Admin Interface_August 2020']}],
#      'li': [{'#text': 'Web-based Interface',
#        'navigablestring': ['Web-based Interface']},
#       {'#text': 'Authentication & authorisation and enhance security protocol',
#        'navigablestring': ['Authentication & authorisation and enhance security protocol']},
#       {'#text': 'Web-based integrated merchant platform',
#        'navigablestring': ['Web-based integrated merchant platform']},
#       {'#text': 'Web-based merchant admin platform',
#        'navigablestring': ['Web-based merchant admin platform']}]}]},
#   {'@class': ['row'],
#    '#text': '5 MVP_October 2020 E-store setup on web Product ratings and review Creation of categories Optimisation module Social management portal',
#    'div': [{'@class': ['number'], '#text': '5', 'navigablestring': ['5']},
#     {'@class': ['bubble'],
#      '#text': 'MVP_October 2020 E-store setup on web Product ratings and review Creation of categories Optimisation module Social management portal',
#      'div': [{'@class': ['arrow'], '#text': ''},
#       {'@class': ['condition'],
#        '#text': 'MVP_October 2020',
#        'navigablestring': ['MVP_October 2020']}],
#      'li': [{'#text': 'E-store setup on web',
#        'navigablestring': ['E-store setup on web']},
#       {'#text': 'Product ratings and review',
#        'navigablestring': ['Product ratings and review']},
#       {'#text': 'Creation of categories',
#        'navigablestring': ['Creation of categories']},
#       {'#text': 'Optimisation module',
#        'navigablestring': ['Optimisation module']},
#       {'#text': 'Social management portal',
#        'navigablestring': ['Social management portal']}]}]}]}

# %%
pd.set_option('display.max_columns', None)
aa1
# Out:
#                                  url   last_update tag status  \
# 0  https://cryptototem.com/lido-ldo/  Aug 11, 2023  []   None
#
#                                    website website_err  \
# 0  https://lido.fi/?utm_source=CryptoTotem
#
#                                       whitepaper_url whitepaper_err  \
# 0  https://cryptototem.com/wp-ico/img/new project...
#
#    bounty_dummy  MVP_dummy                                     overview_block  \
# 0             0          1                Field           Value
# 0  Project...
#
#   overview_err  price_series_avail  \
# 0                                1
#
#                                          description description_err  \
# 0  What is Lido Lido"s liquid staking allows usin...
#
#                               info_block                   info_err  \
# 0  Empty DataFrame
# Columns: []
# Index: []  name 'Tag' is not defined
#
#                                           team_block team_err  \
# 0      Member                Name  \
# 0     Team  ...
#
#                                          social_info social_err
# 0       Social                                   ...

# %%
df_scrape_raw
# Out:
#                                                url scrape_status  \
# 0                https://cryptototem.com/lido-ldo/            OK
# 1              https://cryptototem.com/subdao-gov/            OK
# 2          https://cryptototem.com/story-protocol/            OK
# 3      https://cryptototem.com/solv-protocol-solv/            OK
# 4     https://cryptototem.com/unstoppable-domains/            OK
# ...                                            ...           ...
# 5137  https://cryptototem.com/sexservice-ssio-ico/            OK
# 5138  https://cryptototem.com/vanillaplay-vpy-ico/            OK
# 5139      https://cryptototem.com/okoin-okoin-ico/            OK
# 5140      https://cryptototem.com/erotix--erx-ico/            OK
# 5141     https://cryptototem.com/povcoin-povr-ico/            OK
#
#        last_update      tag status  \
# 0     Aug 11, 2023       []   None
# 1     Dec 01, 2022  [DAICO]   None
# 2     Sep 08, 2023       []   None
# 3     Dec 31, 2022       []   None
# 4     Nov 21, 2022       []   None
# ...            ...      ...    ...
# 5137  May 04, 2018    [ICO]   None
# 5138  May 04, 2018    [ICO]   None
# 5139  May 04, 2018    [ICO]   None
# 5140  May 04, 2018    [ICO]   None
# 5141  Apr 23, 2019    [ICO]   None
#
#                                                 website website_err  \
# 0               https://lido.fi/?utm_source=CryptoTotem
# 1                           https://www.subdao.network/
# 2                        https://www.storyprotocol.xyz/
# 3          https://solv.finance/?utm_source=CryptoTotem
# 4     https://unstoppabledomains.com/?utm_source=Cry...
# ...                                                 ...         ...
# 5137  https://sexservice.io&utm_medium=listing&utm_c...
# 5138  https://www.vanillaplay.io/&utm_medium=listing...
# 5139  https://okoin.io/&utm_medium=listing&utm_campa...
# 5140  https://erotix.io/&utm_medium=listing&utm_camp...
# 5141  https://povcoin.io/&utm_medium=listing&utm_cam...
#
#                                          whitepaper_url whitepaper_err  \
# 0     https://cryptototem.com/wp-ico/img/new project...
# 1     https://cryptototem.com/wp-ico/img/new project...
# 2                                                        NON AVAILABLE
# 3                            https://docs.solv.finance/
# 4                  https://docs.unstoppabledomains.com/
# ...                                                 ...            ...
# 5137  https://sexservice.io/wp/ssio-whitepaper-en-1....
# 5138  https://www.vanillaplay.io/whitepaper/VanillaP...
# 5139  https://cryptototem.com/wp-ico/img/files/7gr4n...
# 5140  https://cryptototem.com/wp-ico/img/files/AyaeT...
# 5141  https://cryptototem.com/wp-ico/img/files/QkeyK...
#
#       bounty_dummy  MVP_dummy  \
# 0              0.0        1.0
# 1              0.0        0.0
# 2              0.0        0.0
# 3              0.0        1.0
# 4              0.0        0.0
# ...            ...        ...
# 5137           0.0        0.0
# 5138           0.0        0.0
# 5139           0.0        0.0
# 5140           0.0        0.0
# 5141           0.0        0.0
#
#                                          overview_block overview_err  \
# 0                   Field           Value
# 0  Project...
# 1                   Field         Value
# 0  Project i...
# 2                   Field          Value
# 0  Project ...
# 3                   Field        Value
# 0  Project in...
# 4                   Field          Value
# 0  Project ...
# ...                                                 ...          ...
# 5137                Field  Value
# 0  Project industry...
# 5138                Field  Value
# 0  Project industry...
# 5139                Field           Value
# 0  Project...
# 5140                Field     Value
# 0  Project indus...
# 5141                Field     Value
# 0  Project indus...
#
#       price_series_avail                                        description  \
# 0                    1.0  What is Lido Lido"s liquid staking allows usin...
# 1                    0.0  What is SubDAO SubDAO is a DAO infrastructure ...
# 2                    0.0  What is Story Protocol Story Protocol was foun...
# 3                    0.0  What is Solv Protocol Solv Protocol is a decen...
# 4                    0.0  What is Unstoppable Domains Unstoppable Domain...
# ...                  ...                                                ...
# 5137                 0.0  What is Sexservice Wallet, Explorer and Live n...
# 5138                 0.0  What is VanillaPlay VanillaPlay eliminates the...
# 5139                 0.0  What is OKOIN Decentralized p2p distribution o...
# 5140                 0.0  What is Erotix The main application of the pla...
# 5141                 0.0  What is POVCOIN POVCOIN develops a platform wh...
#
#      description_err                                         info_block  \
# 0                          category                   label         ...
# 1                          category                 label  \
# 0     D...
# 2                       category               label           value...
# 3                          category                 label  \
# 0     D...
# 4                       category               label           value...
# ...              ...                                                ...
# 5137                       category                 label  \
# 0  Toke...
# 5138                       category                 label  \
# 0  Toke...
# 5139                       category                  label  \
# 0     ...
# 5140                       category                   label  \
# 0    ...
# 5141                       category                   label  \
# 0    ...
#
#      info_err                                         team_block team_err  \
# 0                  Member                Name  \
# 0     Team  ...
# 1                  Member          Name         Role Links
# 0 ...
# 2                  Member                     Name           ...
# 3                  Member                 Name               ...
# 4                 Member             Name                    ...
# ...       ...                                                ...      ...
# 5137                       Empty DataFrame
# Columns: []
# Index: []
# 5138                       Empty DataFrame
# Columns: []
# Index: []
# 5139                       Empty DataFrame
# Columns: []
# Index: []
# 5140                       Empty DataFrame
# Columns: []
# Index: []
# 5141               Member                Name              Ro...
#
#                                             social_info social_err  \
# 0          Social                                   ...
# 1          Social                                Lin...
# 2          Social                                   ...
# 3          Social                                   ...
# 4           Social                                  ...
# ...                                                 ...        ...
# 5137      Social                                    ...
# 5138       Social                                   ...
# 5139       Social                               Link...
# 5140       Social                                Lin...
# 5141        Social                                  ...
#
#                                                 PklPath  TotTimeSec  \
# 0                .\Checkpoints\Cryptototem\lido-ldo.pkl         2.0
# 1              .\Checkpoints\Cryptototem\subdao-gov.pkl         2.0
# 2          .\Checkpoints\Cryptototem\story-protocol.pkl         2.0
# 3      .\Checkpoints\Cryptototem\solv-protocol-solv.pkl         2.0
# 4     .\Checkpoints\Cryptototem\unstoppable-domains.pkl         2.0
# ...                                                 ...         ...
# 5137  .\Checkpoints\Cryptototem\sexservice-ssio-ico.pkl         2.0
# 5138  .\Checkpoints\Cryptototem\vanillaplay-vpy-ico.pkl         2.0
# 5139      .\Checkpoints\Cryptototem\okoin-okoin-ico.pkl         2.0
# 5140      .\Checkpoints\Cryptototem\erotix--erx-ico.pkl         1.0
# 5141     .\Checkpoints\Cryptototem\povcoin-povr-ico.pkl         2.0
#
#      scrape_error
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 5137          NaN
# 5138          NaN
# 5139          NaN
# 5140          NaN
# 5141          NaN
#
# [5142 rows x 25 columns]

# %%
url='https://cryptototem.com/lido-ldo/'#'https://cryptototem.com/maidaan-mnd/'# 'https://cryptototem.com/aethir/' #'https://cryptototem.com/corestarter-cstr/'# 'https://cryptototem.com/anote-music/'# 'https://cryptototem.com/coin98-c98/'# 'https://cryptototem.com/bitwings-bwn/'# 'https://cryptototem.com/lido-ldo/'

def scrape_info_cryptototem(url):

    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')


    # get website
    website=''
    website_err=''
    try:
        tt=convert(soup.find("td", class_="thumbs-holder").find('span', class_='decr'))
        if tt['#text'] == 'Website':
            crypted=tt['@data-u']
            exec('dd='+crypted)
            website=decrypt_CryptoTotem(dd).replace('?utm_source=cryptototem', '')
    except Exception as err:
        website_err=err

    # get whitepaper
    whitepaper_url=''
    whitepaper_err=''
    if soup.find("td", string="Whitepaper") is not None:
        try:
            tt=convert(soup.find("td", string="Whitepaper").find_next_sibling("td").span)
            if tt['#text'] == 'Open':
                crypted=tt['@data-u']
                exec('dd='+crypted)
                whitepaper_url=decrypt_CryptoTotem(dd)
        except Exception as err:
            whitepaper_err=err

    else:
        whitepaper_err='NON AVAILABLE'

    # get Bounty program
    bounty_dummy=0
    if soup.find("div", string="Bounty program") is not None:
        bounty_dummy=1

    # get MVP
    MVP_dummy=0
    if soup.find("h2", string="MVP") is not None:
        MVP_dummy=1

    # get Overview
    overview_err=''
    try:
        tt=convert(soup.find("td", class_="overview-td"))['table'][0]['tr']
        overview_block=pd.DataFrame()
        for el in tt:
            add_row=[x['#text'] for x in el['td']]
            overview_block=pd.concat([overview_block, pd.DataFrame(add_row, index=['Field', 'Value']).T])
    except Exception as err:
        overview_err=err
        overview_block=pd.DataFrame()

    # check if price chart is available (in case, use coingecko API  https://rapidapi.com/collection/coinmarketcap-api)
    price_avail=int(soup.find("div", class_="chart-holder") is not None)

    # get status and tags (ICO, IEO, ...)
    tt=convert(soup.find("h1", class_="ico-title").parent)['div']
    try:
        last_update=tt[0]['#text'].split('Last updated:')[-1].strip()
    except:
        last_update=None
    try:
        tag=[x['#text'] for x in tt[0]['div']]
    except:
        tag=None
    try:
        status=[x['div'][0]['@class'][-1] for x in tt[2]['div']]
    except:
        status=None

    # get description
    description=''
    description_err=''
    try:
        for el in soup.find_all("div", class_="align-left"):
            if el.find('h2') is not None:
                if "What is" in str(el.find('h2')):
                    description=convert(el)['#text']
    except Exception as err:
        description_err=err

    # get Info
    info_err=''
    info_block=pd.DataFrame()
    try:
        for child in soup.find("table", class_="ico-main-table token-info-table").children:
            for td_column in child:
                h2=''
                wait_for_value=True
                for td in td_column:
                    if isinstance(td, Tag):
                        tag_type=td.prettify().split('\n')[0]
                        if tag_type == '<h2>':
                            main_category=td.text
                        elif tag_type == '<strong>':
                            label=td.text
                            wait_for_value=True
                        elif tag_type == '<address>':
                            label='Office address'
                            value=td.text.split('Office address: ')[-1]
                            wait_for_value=False
                        elif tag_type == '<br/>':
                            continue
                    else:   # NavigableString
                        value=td.text.strip()
                        wait_for_value=False
                    if not wait_for_value:
                        info_block=pd.concat([info_block, pd.DataFrame({'category': main_category, 'label': label,
                                                                        'value': value}, index=[0])])
    except Exception as err:
        info_err=err

    # get Team and Advisors
    team_err=''
    team_block=pd.DataFrame()
    try:
        for label, cls  in zip(['Team', 'Advisor'], ['team-members align-center', 'advisors align-center']):
            tt=soup.find("div", class_=cls)
            if tt is not None:
                tt=convert(tt)
                for el in tt['div']:
                    try:
                        pers_name=el['div'][0]['#text']
                    except:
                        pers_name=None
                    try:
                        pers_role = el['div'][1]['#text']
                    except:
                        pers_role=None
                    try:
                        for el1 in el['span']:
                            crypted=el1['@data-u']
                            exec('dd='+crypted)
                            pers_url.append(decrypt_CryptoTotem(dd).replace('\\r', ''))
                    except:
                        pers_url=[]
                    team_block=pd.concat([team_block, pd.DataFrame({'Member': label, 'Name': pers_name, 'Role': pers_role,
                                                                    'Links': [pers_url]}, index=[0])])
    except Exception as err:
        team_err=err

    # social info
    social_err=''
    social_info=pd.DataFrame()
    try:
        tt=convert(soup.find("div", class_="soc-urls"))
        for el in tt['a']:
            try:
                social_name=el['@title'].split(':')[0]
            except:
                social_name=''
            try:
                social_url=el['@href']
            except:
                social_url=''
            social_info=pd.concat([social_info, pd.DataFrame({'Social': social_name, 'Link': social_url}, index=[0])])
    except Exception as err:
        social_err=err


    add_row=pd.DataFrame({'url': url,
                          'last_update': last_update,
                          'tag': [tag],
                          'status': [status],
                          'website': website,
                          'website_err': website_err,
                          'whitepaper_url': whitepaper_url,
                          'whitepaper_err': whitepaper_err,
                          'bounty_dummy': bounty_dummy,
                          'MVP_dummy': MVP_dummy,
                          'overview_block': [overview_block],
                          'overview_err': overview_err,
                          'price_series_avail': price_avail,
                          'description': description,
                          'description_err': description_err,
                          'info_block': [info_block],
                          'info_err': info_err,
                          'team_block': [team_block],
                          'team_err': team_err,
                          'social_info': [social_info],
                          'social_err': social_err}, index=[0])

    return add_row

# %%
df_final.iloc[0]['InfoBlock']
# Out:
#        BlockName          Item  \
# 0        General       Website
# 1        General   White paper
# 2        General      ICO Time
# 3        General       Country
# 4     Token info        Ticker
# 5     Token info      Platform
# 6     Token info  Total supply
# 7      Financial        Raised
# 8      Financial     ICO Price
# 9      Financial     Accepting
# 10  Social media         Links
# 11  Social media
# 12  Social media
# 13  Social media
# 14  Social media
# 15  Social media
# 16  Social media
#
#                                               ItemUrl  \
# 0               http://factom.org?utm_source=icomarks
# 1   https://www.factom.com/devs/docs/guide/factom-...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10    https://bitcointalk.org/index.php?topic=5077258
# 11            https://www.facebook.com/FactomProject/
# 12                         https://twitter.com/factom
# 13                   https://github.com/FactomProject
# 14           https://www.linkedin.com/company/factom/
# 15                 https://discord.com/invite/SxPePjQ
# 16  https://www.youtube.com/channel/UCmxp39JZjPaHH...
#
#                       ItemValue
# 0                         Visit
# 1                          Read
# 2   30 Mar 2015  -  14 May 2015
# 3                           USA
# 4                       Factoid
# 5                    Blockchain
# 6                  0.00 Factoid
# 7                     $ 538,000
# 8       1 Factoid = 0.00588 BTC
# 9                           BTC
# 10                  Bitcointalk
# 11                     Facebook
# 12                      Twitter
# 13                       Github
# 14                     Linkedin
# 15                      Discord
# 16                      Youtube

# %%
df_final.iloc[0]['TeamBlock']
# Out:
#      Member                       Name                             Role  \
# 0      Team                Peter Kirby                        President
# 1      Team                  Paul Snow                              CEO
# 2      Team             David Johnston            Chairman of the Board
# 3      Team                Brian Deery                  Chief Scientist
# 4      Team              Zachary Lynde                              CFO
# 5      Team            Andrew Yashchuk        VP of Product Development
# 6      Team                Abhi Dobhal       VP of Business Development
# 7      Team                 Zeen Zhang            China General Manager
# 8      Team  Mahesh Paolini-Subramanya  EVP of Research and Development
# 9      Team                Laurie Pyle         Executive Vice President
# 10     Team               Jason Nadeau         Executive Vice President
# 11     Team               Michael Beam                   Core Developer
# 12     Team               Robert Baker      Process Integration Manager
# 13     Team           Matt Whittington               Software Developer
# 14     Team            Justin Hanneman                   Lead Developer
# 15     Team              Veena Gondkar                Senior QA Analyst
# 16     Team             Maciek Wciślik                   Lead Developer
# 17     Team           Riccardo Massari                   Lead Developer
# 18     Team                Fabian Król                   Lead Developer
# 19     Team              Marcin Gornik                   Lead Developer
# 20     Team              Steven Masley                   Lead Developer
# 21     Team             Darrell Malone                   Lead Developer
# 22     Team             Adam Jezierski                   Lead Developer
# 23     Team             Krystian Manda                   Lead Developer
# 24     Team            Carl DiClementi                  Product Manager
# 25     Team            JuanJo Comellas  Senior Developer / Security Ops
# 26     Team              Crystal Wiese            Director of Marketing
# 27     Team               Carrie Scott            Director of Personnel
# 28     Team           Courtney Roberts   Digital Communications Manager
# 29  Advisor              Alyse Killeen
# 30  Advisor             Matthew Roszak
# 31  Advisor               Bruce Fenton
# 32  Advisor               Roland Hicks
#
#                                    Extra  \
# 0        Takes part in this project only
# 1        Takes part in this project only
# 2        Takes part in this project only
# 3   Participates in a number of projects
# 4   Participates in a number of projects
# 5        Takes part in this project only
# 6        Takes part in this project only
# 7        Takes part in this project only
# 8        Takes part in this project only
# 9        Takes part in this project only
# 10       Takes part in this project only
# 11       Takes part in this project only
# 12  Participates in a number of projects
# 13       Takes part in this project only
# 14  Participates in a number of projects
# 15       Takes part in this project only
# 16       Takes part in this project only
# 17       Takes part in this project only
# 18       Takes part in this project only
# 19  Participates in a number of projects
# 20       Takes part in this project only
# 21  Participates in a number of projects
# 22       Takes part in this project only
# 23       Takes part in this project only
# 24       Takes part in this project only
# 25  Participates in a number of projects
# 26       Takes part in this project only
# 27       Takes part in this project only
# 28  Participates in a number of projects
# 29      Participates in several projects
# 30  Participates in a number of projects
# 31      Participates in several projects
# 32       Takes part in this project only
#
#                                                 Links
# 0   [https://www.linkedin.com/in/peter-kirby-50034a6]
# 1                [https://www.linkedin.com/in/paulsn]
# 2        [https://www.linkedin.com/in/davidajohnston]
# 3                                                None
# 4                                                None
# 5        [https://www.linkedin.com/in/andrewyashchuk]
# 6            [https://www.linkedin.com/in/abhidobhal]
# 7   [https://www.linkedin.com/in/zeen-zhang-3a41a619]
# 8        [https://www.linkedin.com/in/dieswaytoofast]
# 9           [https://www.linkedin.com/in/lauriepyle/]
# 10  [https://www.linkedin.com/in/jason-nadeau-2bbb...
# 11  [https://www.linkedin.com/in/michael-beam-2365...
# 12                                               None
# 13  [https://www.linkedin.com/in/matt-whittington-...
# 14                                               None
# 15         [https://www.linkedin.com/in/veenagondkar]
# 16              [https://www.linkedin.com/in/maciekw]
# 17            [https://www.linkedin.com/in/maxdrift/]
# 18          [https://www.linkedin.com/in/fabiankrol/]
# 19                                               None
# 20        [https://www.linkedin.com/in/steven-masley]
# 21                                               None
# 22          [https://www.linkedin.com/in/akjezierski]
# 23        [https://www.linkedin.com/in/krystianmanda]
# 24      [https://www.linkedin.com/in/carldiclementi/]
# 25                                               None
# 26            [https://www.linkedin.com/in/xtalwiese]
# 27  [https://www.linkedin.com/in/carrie-scott-282b...
# 28                                               None
# 29        [https://www.linkedin.com/in/alysekilleen/]
# 30       [https://www.linkedin.com/in/matthewroszak/]
# 31          [https://www.linkedin.com/in/brucefenton]
# 32         [https://www.linkedin.com/in/rolandhicks/]

# %%
df_final.iloc[1]['SocialBlock']
# Out:
# [{'stats':      Social  Users     Rating
#   0   Twitter   7273  Very High
#   1  Facebook   1009     Medium,
#   'timeseries': {'Facebook':                          Date  Users
#    0    2018-05-17T07:00:00.000Z    893
#    1    2018-05-18T07:00:00.000Z    893
#    2    2018-05-19T07:00:00.000Z    893
#    3    2018-05-20T07:00:00.000Z    894
#    4    2018-05-21T07:00:00.000Z    894
#    ..                        ...    ...
#    380  2019-07-06T07:00:00.000Z   1011
#    381  2019-07-23T07:00:00.000Z   1010
#    382  2019-08-05T07:00:00.000Z   1009
#    383  2019-08-26T07:00:00.000Z   1009
#    384  2019-09-04T07:00:00.000Z   1009
#
#    [385 rows x 2 columns],
#    'Twitter':                           Date  Users
#    0     2018-05-17T07:00:00.000Z   6108
#    1     2018-05-18T07:00:00.000Z   6108
#    2     2018-05-19T07:00:00.000Z   6106
#    3     2018-05-20T07:00:00.000Z   6097
#    4     2018-05-21T07:00:00.000Z   6102
#    ...                        ...    ...
#    1104  2022-01-28T08:00:00.000Z   7240
#    1105  2022-01-29T08:00:00.000Z   7245
#    1106  2022-01-30T08:00:00.000Z   7247
#    1107  2022-01-31T08:00:00.000Z   7250
#    1108  2022-02-01T08:00:00.000Z   7273
#
#    [1109 rows x 2 columns]}}]

# %%
df_final.columns.values
# Out:
# array(['url', 'ListDownloadedOn', 'NViews', 'VerifiedEmailDummy',
#        'IsSTODummy', 'IsIEODummy', 'Status', 'StartDate', 'EndDate',
#        'LogDurationDays', 'RatingIcomarks', 'TeamSize', 'AdvisorSize',
#        'BountyDummy', 'MVPDummy', 'CountryOriginal', 'Country', 'Region',
#        'SubRegion', 'Dates', 'ICODateStart', 'ICODateEnd', 'IEODateStart',
#        'IEODateEnd', 'IEOLaunchpad', 'STODateStart', 'STODateEnd',
#        'PreSaleDummy', 'PreSaleDateStart', 'PreSaleDateEnd',
#        'WebsiteDummy', 'WebsiteUrl', 'WhitepaperDummy', 'WhitepaperUrl',
#        'WhitepaperDownloaded', 'KYCDummy', 'WhitelistDummy', 'Ticker',
#        'Platform', 'TokenType', 'ERC20Dummy', 'TokenAvailForSale',
#        'TokenTotSupply', 'FundRaisedUSD', 'FundHardCap', 'FundHardCapUSD',
#        'FundSoftCap', 'FundSoftCapUSD', 'CapUSD', 'SuccessPerc',
#        'AcceptedCurr', 'BonusDummy', 'ICOPrice', 'IEOPrice', 'STOPrice',
#        'PriceUSD', 'PreSalePrice', 'PreSalePriceUSD',
#        'SocialSeriesDownloaded', 'PriceSeriesDownloaded', 'StartYear',
#        'StartMonth', 'StartQuarter', 'SocialCount',
#        'LogWhitepaperWordCount', 'CryptoFearGreedIndex',
#        'CryptoFearGreedClass', 'ICORegulation', 'ICEAIndex',
#        'UCRYPolicyIndex', 'UCRYPriceIndex', 'NFTsAttentionIndex',
#        'CBDCUncertaintyIndex', 'CBDCAttentionIndex', 'CBECIPowerDemand',
#        'CBECIElectConsump', 'CBECIGreenhouseEmiss', 'CBECIHashrateShare',
#        'ESGify_E', 'ESGify_S', 'ESGify_G', 'ESGify_N',
#        'ESGify_ESGsubclass', 'FINBERT-Tone_FinSentiment',
#        'FINBERT-Tone_FinSentimentsubclass', 'FINBERT-ESG_E',
#        'FINBERT-ESG_S', 'FINBERT-ESG_G', 'FINBERT-ESG_N',
#        'FINBERT-ESG_ESGsubclass', 'MansouriMomtaz_E', 'MansouriMomtaz_S',
#        'MansouriMomtaz_G', 'MansouriMomtaz_N', 'InfoBlock', 'TeamBlock',
#        'SocialBlock', 'MarketPriceSeries', 'MarketPriceSeriesCoinMarket',
#        'CategoryAIDummy', 'CategoryArtDummy', 'CategoryBankingDummy',
#        'CategoryBigDataDummy', 'CategoryBusinessDummy',
#        'CategoryCharityDummy', 'CategoryCommunicationDummy',
#        'CategoryCryptocurrencyDummy', 'CategoryDeFiDummy',
#        'CategoryEducationDummy', 'CategoryElectronicsDummy',
#        'CategoryEnergyDummy', 'CategoryEntertainmentDummy',
#        'CategoryExchange&LaunchpadDummy', 'CategoryGamblingDummy',
#        'CategoryHealthDummy', 'CategoryInfrastructureDummy',
#        'CategoryInternetDummy', 'CategoryInvestmentDummy',
#        'CategoryLegalDummy', 'CategoryManufacturingDummy',
#        'CategoryMarketingAgencyDummy', 'CategoryMediaDummy',
#        'CategoryOtherDummy', 'CategoryPlatformDummy',
#        'CategoryRealestateDummy', 'CategoryRetailDummy',
#        'CategorySmartContractDummy', 'CategorySoftwareDummy',
#        'CategorySportsDummy', 'CategoryTourismDummy',
#        'CategoryUnknownDummy', 'CategoryVirtualRealityDummy',
#        'SocialBitcointalkDummy', 'SocialFacebookDummy',
#        'SocialTelegramDummy', 'SocialTwitterDummy', 'SocialMediumDummy',
#        'SocialYoutubeDummy', 'SocialRedditDummy', 'SocialGithubDummy',
#        'SocialDiscordDummy', 'SocialVKDummy', 'SocialLinkedinDummy',
#        'SocialSlackDummy', 'SocialInstagramDummy'], dtype=object)

# %%
df_final=joblib.load(os.path.join(CHECKPOINT_FOLDER, 'df_final_Scientific_Data.pkl'))
df_final
# Out:
#                                         url ListDownloadedOn  NViews  \
# 0            https://icomarks.ai/ico/factom       06/02/2023   14866
# 1       https://icomarks.ai/ico/bitcrystals       06/02/2023   15255
# 2             https://icomarks.ai/ico/augur       06/02/2023   19598
# 3             https://icomarks.ai/ico/safex       06/02/2023    9577
# 4          https://icomarks.ai/ico/digixdao       06/02/2023   17118
# ...                                     ...              ...     ...
# 8274         https://icomarks.ai/ico/anuvia       06/02/2023     122
# 8275          https://icomarks.ai/ico/mthub       06/02/2023      93
# 8276       https://icomarks.ai/ico/calvaria       06/02/2023    2238
# 8277     https://icomarks.ai/ico/host-games       06/02/2023   17636
# 8278  https://icomarks.ai/ico/synthetics-ai       06/02/2023   17727
#
#       VerifiedEmailDummy  IsSTODummy  IsIEODummy    Status   StartDate  \
# 0                      0           0           0     Ended  2015-03-30
# 1                      0           0           0   Trading  2015-08-04
# 2                      0           0           0   Trading  2015-08-17
# 3                      0           0           0     Ended  2016-01-01
# 4                      0           0           0   Trading  2016-03-29
# ...                  ...         ...         ...       ...         ...
# 8274                   1           0           0  Upcoming  2150-01-01
# 8275                   0           0           0  Upcoming  2150-01-01
# 8276                   1           0           0  Upcoming  2150-01-01
# 8277                   0           0           0  Upcoming  2150-01-01
# 8278                   0           0           0  Upcoming  2150-01-01
#
#           EndDate  LogDurationDays  ...  SocialTwitterDummy  \
# 0     14 May 2015         1.662758  ...                   1
# 1     15 Sep 2015         1.633468  ...                   1
# 2     01 Oct 2015         1.662758  ...                   1
# 3     31 Jan 2016         1.491362  ...                   1
# 4       30-mar-16         0.301030  ...                   1
# ...           ...              ...  ...                 ...
# 8274          TBA              NaN  ...                   0
# 8275          TBA              NaN  ...                   0
# 8276          TBA              NaN  ...                   1
# 8277          TBA              NaN  ...                   1
# 8278          TBA              NaN  ...                   1
#
#       SocialMediumDummy  SocialYoutubeDummy  SocialRedditDummy  \
# 0                     0                   1                  0
# 1                     0                   0                  0
# 2                     1                   1                  1
# 3                     0                   1                  1
# 4                     1                   0                  1
# ...                 ...                 ...                ...
# 8274                  0                   0                  0
# 8275                  0                   0                  0
# 8276                  1                   1                  1
# 8277                  1                   1                  1
# 8278                  0                   0                  0
#
#       SocialGithubDummy SocialDiscordDummy SocialVKDummy SocialLinkedinDummy  \
# 0                     1                  1             0                   1
# 1                     0                  0             0                   0
# 2                     1                  0             0                   0
# 3                     1                  0             0                   0
# 4                     1                  0             0                   0
# ...                 ...                ...           ...                 ...
# 8274                  0                  0             0                   0
# 8275                  0                  0             0                   0
# 8276                  0                  1             0                   0
# 8277                  0                  0             0                   0
# 8278                  0                  0             0                   0
#
#      SocialSlackDummy SocialInstagramDummy
# 0                   0                    0
# 1                   0                    0
# 2                   1                    0
# 3                   0                    0
# 4                   0                    0
# ...               ...                  ...
# 8274                0                    0
# 8275                0                    0
# 8276                0                    0
# 8277                0                    0
# 8278                0                    0
#
# [8279 rows x 145 columns]
